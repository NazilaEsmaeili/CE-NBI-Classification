# %% [markdown]
# #COLAB Load
# (uncomment if colab used and change paths accordingly in next section)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # Different parameters, train-test split and paths

# %%
##params

test_percent = 0.2# @param {type: "slider", min:0.05, max:0.5, step:0.05}
BATCH_SIZE = 32# @param {type: "slider", min:0, max:128 ,step:8}
epoch_no = 30 #@param {type: "slider", min:1, max:50}
no_of_channels = 3# @param {type: "slider", min:1, max:4}

##Paths

dataset_path = "C:/Users/AdminUser/Desktop/Ensemble Model/Dataset/aug_train"
model_savepath = "C:/Users/AdminUser/Desktop/Ensemble Model/Models/efficientnetb0_0.h5
#dataset_path = "/content/drive/MyDrive/data/comb_dt_splits/aug_train"
#model_savepath = "/content/drive/MyDrive/affan/effnet.h5"

# %% [markdown]
# #Keras Architecture and other Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import random
import cv2
from tqdm import tqdm
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split

from tensorflow.keras import layers
from tensorflow.keras import preprocessing

#from google.colab.patches import cv2_imshow
import gc

# %%
from tensorflow.keras.applications import EfficientNetB0
model = EfficientNetB0
#model = EfficientNetB0(weights='imagenet')

# %% [markdown]
# # Data Load into Numpy array with respective labels and Split

# %%
DATADIR = dataset_path
FOLDERS = ["B","M"]       #one folder is for M and one for B
CATEGORIES = ["B", "M"]   #there are two categories here for the target variable
NUM_CLASSES = 2           #two classes for the classification
IMG_SIZE = 224            #size of an input image

# %%
# Data Read Function

def read_data():
    images = []
    labels = []
    img_paths = []
    data = []

    for category,folder in zip(CATEGORIES,FOLDERS):   # do B and M 
        path = os.path.join(DATADIR,folder)           # create path to B and M  
        class_num = CATEGORIES.index(category)        # get the classification  (0 or a 1). 0=B and 1=M
        
        for i,img_path in enumerate(tqdm(os.listdir(path))):            # iterate over each image 
            try:
                img_array = cv2.imread(os.path.join(path,img_path))     # convert to array
                img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size                
                img_paths.append(os.path.join(path,img_path))
                
                data.append([img_array, class_num])  # add this to our training_data
                images.append(img_array)
                labels.append(class_num)
            except Exception as e:                   # in the interest in keeping the output clean...
                pass

    images = np.array(images)                         # output images into np array
    images = np.asarray(images).astype(np.float32)
    labels = np.array(labels)                        # output labels into np array
    

    return images,labels

# %%
images,labels = read_data()           # Function call read data
print(len(images))                    # to check the length
print(len(labels))
images.shape                          # to match with input shape to the Architecture
# Out:
# 100%|██████████| 6080/6080 [00:11<00:00, 548.59it/s]
# 100%|██████████| 5600/5600 [00:09<00:00, 610.56it/s]
# 11680
# 11680
# (11680, 224, 224, 3)

# %%
images = images/255    ##rescaling for less computational power
X = images

##train-test split
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size = test_percent, random_state=42)

# %% [markdown]
# #Define the Architecture and Tensorflow GPU strategy

# %%
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, no_of_channels))
    outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(inputs)

    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"]
    )

model.summary()
# Out:
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, 2)                 4052133
# =================================================================
# Total params: 4,052,133
# Trainable params: 4,010,110
# Non-trainable params: 42,023
# _________________________________________________________________

# %% [markdown]
# #Training and Save trained Model

# %%
histories = []
scores = []

##one_hot: scale into 0-1 vector 
y_train = tf.one_hot(y_train, NUM_CLASSES)    
y_test = tf.one_hot(y_test, NUM_CLASSES)


## Training step
history = model.fit(X_train,y_train, epochs=epoch_no, validation_data=(X_test,y_test), verbose=2,
                 batch_size=BATCH_SIZE , shuffle = 'true')

gc.collect()

## Metrics for plotting
histories.append(history)
score = model.evaluate(X_test,y_test, verbose=0)
scores.append(score)
# Out:
# Epoch 1/30
# 292/292 - 93s - loss: 0.9213 - accuracy: 0.6979 - val_loss: 0.7713 - val_accuracy: 0.4683
# Epoch 2/30
# 292/292 - 73s - loss: 0.5488 - accuracy: 0.7653 - val_loss: 0.6543 - val_accuracy: 0.5522
# Epoch 3/30
# 292/292 - 73s - loss: 0.4628 - accuracy: 0.7794 - val_loss: 0.3717 - val_accuracy: 0.8275
# Epoch 4/30
# 292/292 - 73s - loss: 0.3570 - accuracy: 0.8389 - val_loss: 0.5048 - val_accuracy: 0.7757
# Epoch 5/30
# 292/292 - 74s - loss: 0.3440 - accuracy: 0.8474 - val_loss: 716.5319 - val_accuracy: 0.4756
# Epoch 6/30
# 292/292 - 73s - loss: 0.3814 - accuracy: 0.8196 - val_loss: 0.2759 - val_accuracy: 0.8904
# Epoch 7/30
# 292/292 - 73s - loss: 0.3564 - accuracy: 0.8431 - val_loss: 0.2936 - val_accuracy: 0.8763
# Epoch 8/30
# 292/292 - 73s - loss: 0.2490 - accuracy: 0.8907 - val_loss: 0.1943 - val_accuracy: 0.9212
# Epoch 9/30
# 292/292 - 73s - loss: 0.2280 - accuracy: 0.9067 - val_loss: 0.2248 - val_accuracy: 0.9114
# Epoch 10/30
# 292/292 - 73s - loss: 0.1740 - accuracy: 0.9297 - val_loss: 0.2175 - val_accuracy: 0.9105
# Epoch 11/30
# 292/292 - 73s - loss: 0.1526 - accuracy: 0.9394 - val_loss: 0.3566 - val_accuracy: 0.8767
# Epoch 12/30
# 292/292 - 77s - loss: 0.1286 - accuracy: 0.9493 - val_loss: 0.1889 - val_accuracy: 0.9255
# Epoch 13/30
# 292/292 - 78s - loss: 0.1172 - accuracy: 0.9558 - val_loss: 0.3223 - val_accuracy: 0.8673
# Epoch 14/30
# 292/292 - 78s - loss: 0.1109 - accuracy: 0.9610 - val_loss: 0.2332 - val_accuracy: 0.9075
# Epoch 15/30
# 292/292 - 78s - loss: 0.0960 - accuracy: 0.9681 - val_loss: 0.3321 - val_accuracy: 0.8754
# Epoch 16/30
# 292/292 - 75s - loss: 0.0967 - accuracy: 0.9652 - val_loss: 0.2786 - val_accuracy: 0.9028
# Epoch 17/30
# 292/292 - 73s - loss: 0.0762 - accuracy: 0.9722 - val_loss: 0.2846 - val_accuracy: 0.9182
# Epoch 18/30
# 292/292 - 75s - loss: 0.0912 - accuracy: 0.9654 - val_loss: 0.3244 - val_accuracy: 0.8938
# Epoch 19/30
# 292/292 - 75s - loss: 0.0859 - accuracy: 0.9693 - val_loss: 0.1736 - val_accuracy: 0.9366
# Epoch 20/30
# 292/292 - 73s - loss: 0.0593 - accuracy: 0.9795 - val_loss: 0.2021 - val_accuracy: 0.9422
# Epoch 21/30
# 292/292 - 74s - loss: 0.0556 - accuracy: 0.9788 - val_loss: 0.1910 - val_accuracy: 0.9354
# Epoch 22/30
# 292/292 - 73s - loss: 0.0604 - accuracy: 0.9775 - val_loss: 0.2565 - val_accuracy: 0.9195
# Epoch 23/30
# 292/292 - 74s - loss: 0.0939 - accuracy: 0.9658 - val_loss: 0.2589 - val_accuracy: 0.9011
# Epoch 24/30
# 292/292 - 73s - loss: 0.1046 - accuracy: 0.9664 - val_loss: 0.2895 - val_accuracy: 0.8904
# Epoch 25/30
# 292/292 - 74s - loss: 0.0824 - accuracy: 0.9721 - val_loss: 0.1881 - val_accuracy: 0.9414
# Epoch 26/30
# 292/292 - 74s - loss: 0.0409 - accuracy: 0.9865 - val_loss: 0.2218 - val_accuracy: 0.9371
# Epoch 27/30
# 292/292 - 73s - loss: 0.0402 - accuracy: 0.9858 - val_loss: 0.2478 - val_accuracy: 0.9144
# Epoch 28/30
# 292/292 - 74s - loss: 0.0470 - accuracy: 0.9829 - val_loss: 0.4754 - val_accuracy: 0.8570
# Epoch 29/30
# 292/292 - 73s - loss: 0.0438 - accuracy: 0.9842 - val_loss: 0.2357 - val_accuracy: 0.9358
# Epoch 30/30
# 292/292 - 74s - loss: 0.0375 - accuracy: 0.9866 - val_loss: 0.2039 - val_accuracy: 0.9473

# %%
model.save(model_savepath)
print("Saved model to disk")
# Out:
# C:\Users\AdminUser\anaconda3\envs\ensemble_gpu\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Saved model to disk

# %% [markdown]
# #Plots

# %%
score = scores[0]
print (score)
# Out:
# [0.20391623675823212, 0.9473459124565125]

# %%
def plot_accuracy(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("Accuracy")
    plt.ylabel("Accuracy")
    plt.xlabel("Epochs")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()

plot_accuracy(history)

# %%
def plot_loss(hist):
    plt.plot(hist.history["loss"])
    plt.plot(hist.history["val_loss"])
    plt.title("Loss")
    plt.ylabel("Loss")
    plt.xlabel("Epochs")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()

plot_loss(history)
